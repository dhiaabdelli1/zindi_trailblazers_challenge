# %%
import pandas as pd

# %%
train = pd.read_csv('data/Train.csv')
train.shape
# Out:
# (2822, 63)

# %%
info = pd.read_csv('data/variable_descriptions.csv')
pd.set_option('display.max_colwidth', 200)

# %%
info
# Out:
#         Column  \
# 0        dw_00
# 1        dw_01
# 2        dw_02
# 3        dw_03
# 4        dw_04
# 5        dw_05
# 6        dw_06
# 7        dw_07
# 8        dw_08
# 9        dw_09
# 10       dw_10
# 11       dw_11
# 12       dw_12
# 13       dw_13
# 14      psa_00
# 15      psa_01
# 16      psa_02
# 17      psa_03
# 18      psa_04
# 19      stv_00
# 20      stv_01
# 21      car_00
# 22      car_01
# 23      lln_00
# 24      lln_01
# 25      lan_00
# 26      lan_01
# 27      lan_02
# 28      lan_03
# 29      lan_04
# 30      lan_05
# 31      lan_06
# 32      lan_07
# 33      lan_08
# 34      lan_09
# 35      lan_10
# 36      lan_11
# 37      lan_12
# 38      lan_13
# 39      lan_14
# 40       pg_00
# 41       pg_01
# 42       pg_02
# 43       pg_03
# 44       pg_04
# 45      lgt_00
# 46       pw_00
# 47       pw_01
# 48       pw_02
# 49       pw_03
# 50       pw_04
# 51       pw_05
# 52       pw_06
# 53       pw_07
# 54       pw_08
# 55  ADM4_PCODE
# 56         lat
# ...
